# %% [markdown]
# # <u>SQL / Postgres</u>

# %% [markdown]
# # 0.0. Before we start...
# The three tables that are needed can be downloaded here: https://drive.google.com/drive/folders/11eDW6Bt04xP9wEpXNbzin8y49Nk2EaFR

# %% [markdown]
# ### To give everyone a sense of what these tables look like...

# %% [markdown]
# ### Counties Table
# ![counties_img.png](attachment:counties_img.png)

# %% [markdown]
# ### Sales Table
# ![sales_img.png](attachment:sales_img.png)

# %% [markdown]
# ### Stores Table
# ![stores_img.png](attachment:stores_img.png)

# %% [markdown]
# ## 0.1. Create a database called 'sales_data' and connect to it.

# %% [markdown]
# ## 0.2. Create tables within Postgres using the following column names/data types
# ```
# Counties:
#     county TEXT,
#     county_number INT,
#     population INT
# ```
#
# ```
# Sales:
#     store INT,
#     county_number INT,
#     county TEXT,
#     category_name TEXT,
#     vendor_number INT,
#     vendor TEXT,
#     item INT,
#     description TEXT,
#     pack INT,
#     liter_size REAL,
#     btl_price REAL,
#     bottle_qty INT,
#     total REAL
# ```
# ```
# Stores:
#     store INT,
#     store_name TEXT,
#     store_status TEXT,
#     store_address TEXT
# ```

# %% [markdown]
# ## 0.3. Load in the saved datasets into the created tables.
#
# Within the SQL Shell, we could do this by doing the following:
# ```
# \copy counties from 'ABSOLUTE_PATH_TO_COUNTIES.CSV' HEADER CSV
# ```
# ```
# \copy sales from 'ABSOLUTE_PATH_TO_SALES.CSV' HEADER CSV
# ```
# ```
# \copy stores from 'ABSOLUTE_PATH_TO_STORES.CSV' HEADER CSV
# ```
#
# To exemplify how it would be within my personal laptop, I would open the SQL Shell, connect to the the 'sales_data' database that we just created, and input the following command:
# ```
# \copy counties from '/Users/b330-admin/Desktop/CodeOp/assignments/test2/preprocessed_counties.csv' HEADER CSV
# ```
#
# This would only load the 'counties' tables into Postgres so you would need to do this also for the sales and stores tables as well.
#
# If you have any problems with this, please message me on Slack :)

# %% [markdown]
# ## Now we could move on to the actual test.
# ## <u>For each of the bullet points, please insert the proper SQL command in the space provided.</u>

# %% [markdown]
# ## 1.1. Using the 'sales' and 'counties' tables...

# %% [markdown]
# - For each sale, perform a query to get the total price of the sale, the county name, the county number, and the county's population.

# %% [markdown]
# (Insert SQL query here)

# %% [markdown]
# - For each sale, perform a query to get the total price of the sale, the county name, the county number and the county's population if the total is above 100 dollars.

# %% [markdown]
# (Insert SQL query here)

# %% [markdown]
# - For the entire sales table, get the average bottle quantity and average total

# %% [markdown]
# (Insert SQL query here)

# %% [markdown]
# - For the entire sales table, get the count of records/rows that belong to the 'Scott' county.

# %% [markdown]
# (Insert SQL query here)

# %% [markdown]
# ## 1.2. Using the 'stores' and 'sales' tables...

# %% [markdown]
# - Using an outer join with stores and sales, perform a query to count how many total rows there are

# %% [markdown]
# (Insert SQL query here)

# %% [markdown]
# - Using an inner join with stores and sales, perform a query to count how many total rows there are

# %% [markdown]
# (Insert SQL query here)

# %% [markdown]
# - Using a right join with stores and sales, perform a query to count how many total rows there are

# %% [markdown]
# (Insert SQL query here)

# %% [markdown]
# - If you want to join the stores table to the sales table, what would be the primary and foreign keys?

# %% [markdown]
# (Insert SQL query here)

# %% [markdown]
# - For each sale, perform a query to get the item, description, total, name of the store and store status if the store status is active (i.e. store_status is A)

# %% [markdown]
# (Insert SQL query here)

# %% [markdown]
# - For each sale, perform a query to get the average total for all inactive (i.e. store_status is I) stores

# %% [markdown]
# (Insert SQL query here)

# %% [markdown]
# - What are the store names for each sale?

# %% [markdown]
# (Insert SQL query here)

# %% [markdown]
# ## 1.3 Using the 'stores', 'sales' and 'counties' tables...

# %% [markdown]
# - Perform a query to join the stores, sales and counties tables

# %% [markdown]
# (Insert SQL query here)

# %% [markdown]
# - Perform a query that gets the store name, store status, total, and county number for each sale.

# %% [markdown]
# (Insert SQL query here)

# %% [markdown]
# - Perform a query that gets the store name, store status, total, and county number for each sale if it is active, has a total above 100, and has a population > 5000

# %% [markdown]
# (Insert SQL query here)

# %% [markdown]
# ## 1.4 Testing your knowledge...

# %% [markdown]
# - Could you explain the difference between an inner join and an outer join?

# %% [markdown]
# (Insert short (~1-2 sentences) answer here)

# %% [markdown]
# - Say that you're doing a left join between Table A and another table called Table B. If there's a row in Table B that does not have a corresponding row in Table A, will that row be included?

# %% [markdown]
# (Insert short (~1-2 sentences) answer here)

# %% [markdown]
# - Using both Table A and Table B, if there's a row in Table A that does not have a corresponding row in Table B, will that row be included?

# %% [markdown]
# (Insert short (~1-2 sentences) answer here)
